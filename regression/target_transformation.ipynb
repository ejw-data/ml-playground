# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Generate synthetic data with an exponential relationship
np.random.seed(42)
X = np.sort(5 * np.random.rand(100, 1), axis=0)
y = 2 * np.exp(0.5 * X) + np.random.normal(0, 0.1, X.shape[0])

plt.scatter(X[:,0],y[:,0], s=20, label="Original Data")

# %%
# Apply logarithmic transformation to X and generate y accordingly
y_log = np.log(y)

# %%
plt.scatter(X[:,0],y_log[:,0], s=20, label="Transformed Y (log(Y))")

# %%
# Create a Linear Regression model
model = LinearRegression()

# Train the model on the transformed data
model.fit(X, y_log)

# Make predictions on the transformed data
y_pred_log = model.predict(X)

# %%
# Calculate the mean squared error on the transformed data
mse = mean_squared_error(y, y_pred)
print("Mean Squared Error (Transformed Data):", mse)

# X = [ i[0] for i in X]
# Plot the original data and the linear regression line on the transformed data
plt.figure(figsize=(8, 6))
plt.scatter(X[:,0],y_log[:,0], s=20, label="Original Data")
plt.plot(X[:,0], y_pred_log[:,0], color='r', label="Linear Regression on Transformed Data")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.title("Linear Regression with Logarithmic Transformation")
plt.show()
# Out:
# Mean Squared Error (Transformed Data): 10.729049247035766
